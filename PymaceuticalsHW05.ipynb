# %%
import os
import csv
import pandas as pd
import collections as ct
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
mouse_path = 'C:/Users/bassa/projects/Pyma/Resources/'
mouse_csv_file = 'mouse_data.csv'
mouse_csv_filepath = os.path.join(mouse_path, mouse_csv_file)
print(mouse_csv_filepath)
# Out:
# C:/Users/bassa/projects/Pyma/Resources/mouse_data.csv

# %%
mouse_df = pd.read_csv(mouse_csv_filepath)

# %%
mouse_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
test_path = 'C:/Users/bassa/projects/Pyma/Resources/'
test_csv_file = 'clinicaldata.csv'
test_csv_filepath = os.path.join(test_path, test_csv_file)
print(test_csv_filepath)
# Out:
# C:/Users/bassa/projects/Pyma/Resources/clinicaldata.csv

# %%
test_df = pd.read_csv(test_csv_filepath)

# %%
# Read the Mouse and Drug Data and the Clinical Trial Data

print(mouse_df.to_string())

#each row has a mouse measured at a given timepoint.  The timepoints go to 45 and are measured every 5  units. 
#The metastatic sites and the tumor volumme are wat change overtime.
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# 5        h246          0           45.000000                 0
# 6        p189          0           45.000000                 0
# 7        n923          0           45.000000                 0
# 8        q119          0           45.000000                 0
# 9        f993          0           45.000000                 0
# 10       z234          0           45.000000                 0
# 11       b559          0           45.000000                 0
# 12       y260          0           45.000000                 0
# 13       x930          0           45.000000                 0
# ...

# %%
print(test_df.to_string())


#these Mice have a different ID than the other sample each has a list of the drug that was tested.
# Out:
#     Mouse ID       Drug
# 0       f234   Stelasyn
# 1       x402   Stelasyn
# 2       a492   Stelasyn
# 3       w540   Stelasyn
# 4       v764   Stelasyn
# 5       o848   Stelasyn
# 6       z314   Stelasyn
# 7       g989   Stelasyn
# 8       m269   Stelasyn
# 9       a963   Stelasyn
# 10      t451   Stelasyn
# 11      p981   Stelasyn
# 12      k510   Stelasyn
# 13      h333   Stelasyn
# 14      c402   Stelasyn
# 15      j984   Stelasyn
# 16      w697   Stelasyn
# 17      s619   Stelasyn
# 18      g867   Stelasyn
# 19      k862   Stelasyn
# 20      i901   Stelasyn
# 21      b879   Stelasyn
# 22      p387   Stelasyn
# 23      a366   Stelasyn
# 24      s565   Stelasyn
# 25      j755   Naftisol
# 26      e213   Naftisol
# 27      e584   Naftisol
# 28      e291   Naftisol
# 29      z795   Naftisol
# 30      x264   Naftisol
# 31      v199   Naftisol
# 32      r701   Naftisol
# 33      t724   Naftisol
# 34      a818   Naftisol
# 35      v295   Naftisol
# 36      m133   Naftisol
# ...

# %%
# Combine the data into a single dataset


# Display the data table for preview

# %%
clinical_data_complete = pd.merge(test_df, mouse_df, how="left", on=["Mouse ID", "Mouse ID"])

# %%
print(clinical_data_complete.to_string())
# Out:
#      Mouse ID       Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        f234   Stelasyn          0           45.000000                 0
# 1        f234   Stelasyn          5           47.313491                 0
# 2        f234   Stelasyn         10           47.904324                 0
# 3        f234   Stelasyn         15           48.735197                 1
# 4        f234   Stelasyn         20           51.112713                 2
# 5        f234   Stelasyn         25           52.178602                 2
# 6        f234   Stelasyn         30           56.873817                 2
# 7        f234   Stelasyn         35           57.748758                 2
# 8        x402   Stelasyn          0           45.000000                 0
# 9        x402   Stelasyn          5           46.327570                 1
# 10       x402   Stelasyn         10           46.886962                 1
# 11       x402   Stelasyn         15           49.119948                 1
# ...

# %%
#from my observation from scimming through the combined file it appears that Capomulin has the only decrease in tumor volume.

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
#getting the mean of the tumor volume by drug and timeppoint 

tumor_vol_mean = clinical_data_complete.groupby(["Drug", "Timepoint"]).mean()["Tumor Volume (mm3)"]

tumor_vol_mean = pd.DataFrame(tumor_vol_mean)


tumor_vol_mean
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
# ...                                 ...
# Zoniferol 25                  55.432935
#           30                  57.713531
#           35                  60.089372
#           40                  62.916692
#           45                  65.960888
#
# [100 rows x 1 columns]

# %%
#samething with margin of error

tumor_vol_mean = clinical_data_complete.groupby(["Drug", "Timepoint"]).mean()["Tumor Volume (mm3)"]

tumor_vol_mean = pd.DataFrame(tumor_vol_mean)


tumor_vol_mean
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
# ...                                 ...
# Zoniferol 25                  55.432935
#           30                  57.713531
#           35                  60.089372
#           40                  62.916692
#           45                  65.960888
#
# [100 rows x 1 columns]
